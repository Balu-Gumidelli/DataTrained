# %% [markdown]
# # Baseball Case Study
# # Problem Statement:
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Dataset:

# %%
df=pd.read_csv("baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # EDA:

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %%
import seaborn as sns  #import seaborn for visualization
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# From the above information we can observe that the count has no change among all the columns.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# Even though none of the column containing object data type,let's check for the empty values in the data set

# %%
df.loc[df['W']==" "]
# Out:
# Empty DataFrame
# Columns: [W, R, AB, H, 2B, 3B, HR, BB, SO, SB, RA, ER, ERA, CG, SHO, SV, E]
# Index: []

# %% [markdown]
# Hence,our dataset is free from null spaces.

# %% [markdown]
# So,let's move on to the Data Visualization.

# %% [markdown]
# # Data Visualization:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Univariate Analysis:

# %%
plt.figure(figsize=(10,20))
plotnumber = 1
for i in df:
    if plotnumber<=18:
        p=plt.subplot(5,5,plotnumber)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(15,17))
plotnumber=1
for column in df:
    if plotnumber<=18:
        ax = plt.subplot(5,5,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=11)
    plotnumber+=1
plt.show()

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize=[20,20])
plotnumber=1
for i in df:
    if plotnumber<=18:
        p=plt.subplot(5,4,plotnumber)
        sns.scatterplot(x=df[i],y=df['W'],hue=df["W"])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize = [20,15])
plotnumber=1
for i in df:
    if plotnumber<=18:
        p=plt.subplot(5,4,plotnumber)
        sns.scatterplot(x=df[i],y= df['W'],hue=df['W'])
        plt.xlabel(i,fontsize=10)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# # Multivariate Analysis:

# %%
sns.pairplot(df,hue="W")

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
df_new.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.xticks(rotation=360)
plt.title('Correlation between Target and features ',fontsize=15)
plt.show()

# %% [markdown]
# By the above visualisations,we can clearly observe that 'CG' and 'H' are least correlated with Target so let's drop that two columns.

# %%
df.drop(columns=['H','CG'],axis=1,inplace=True)

# %% [markdown]
# # Outliers Check:

# %%
df.plot(kind='box',fontsize=10,figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can clearly see that outliers are present in 'R' , 'ERA' , 'SHO' , 'SV' and 'E'

# %% [markdown]
# # Removing the Outliers:

# %%
col=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(col))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 6    87  764  5567  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  642  604  3.74   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  733  680  4.24    9  45  119
# 11   86  729  5459  278  26  230  486  1392  121  618  572  3.57   13  39   85
# ...

# %%
df.shape
# Out:
# (30, 15)

# %%
df_new.shape
# Out:
# (29, 15)

# %% [markdown]
# # Percentage of Loss:

# %%
Data_loss = (30-29)/30*100

# %%
Data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# # Skewness:

# %% [markdown]
# Let's check for skewness

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
col=['SHO','SV','E']

# %%
from sklearn.preprocessing import PowerTransformer
Scaler=PowerTransformer(method='yeo-johnson')

# %%
df_new[col] = Scaler.fit_transform(df_new[col].values)

# %%
df_new[col]
# Out:
#          SHO        SV         E
# 0  -0.787002  1.532753 -0.348265
# 1   0.236737  0.312020 -0.540820
# 2  -0.252844 -0.664137 -1.326125
# 3  -0.513555 -0.820689  0.650818
# 4   0.236737 -1.149165 -0.540820
# 6  -2.064039  0.677176  0.082858
# 7  -0.252844  0.052325 -1.588197
# 8   0.236737  1.908137  0.237592
# 9  -0.252844 -0.365006  0.383386
# 10 -0.513555  0.312020  1.554265
# 11  0.468029 -0.512328 -0.641926
# 12  0.236737  0.436838  0.082858
# 13  0.236737  0.312020  0.161388
# 14  0.908147 -2.498840  1.810553
# 15  0.908147  2.084917  0.311562
# 16  0.468029  1.333006  1.669209
# 17  2.090856  0.677176  1.203715
# 18 -1.075340 -0.365006  1.430810
# 19 -0.787002 -1.149165 -0.167685
# 20  0.691583  0.906024 -0.348265
# 21  0.468029 -0.221934 -0.167685
# 22  0.236737 -1.149165 -1.588197
# 23 -0.252844  0.183904 -0.167685
# 24 -1.075340 -1.149165  1.472959
# 25  2.090856  0.558509 -1.870191
# 26  1.521828 -0.221934 -1.454792
# 27  0.236737  0.183904 -0.540820
# ...

# %% [markdown]
# Now let's check the skew again.

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# # Data Preprocessing:

# %%
x=df_new.drop('W',axis=1)
y=df_new['W']

# %% [markdown]
# # Scaling:

# %%
from sklearn.preprocessing import StandardScaler
Scaler=StandardScaler()
x=pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB        2B        3B        HR        BB        SO  \
# 0   0.959398  0.830084  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  1.255894  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.752672  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.412514 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# ...

# %% [markdown]
# # Checking VIF:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#      VIF values Features
# 0      6.219825        R
# 1      9.828077       AB
# 2      2.683572       2B
# 3      3.196853       3B
# 4      7.369072       HR
# 5      2.686472       BB
# 6      2.741072       SO
# 7      1.757901       SB
# 8    179.096825       RA
# 9   1754.643859       ER
# 10  1310.260128      ERA
# 11     3.086344      SHO
# 12     4.021573       SV
# 13     1.742105        E

# %% [markdown]
# We can observe that the VIF value is more for 'ER'

# %%
x.drop('ER',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values Features
# 0     4.352902        R
# 1     3.177214       AB
# 2     2.597985       2B
# 3     3.072775       3B
# 4     4.949255       HR
# 5     2.561982       BB
# 6     2.661842       SO
# 7     1.680467       SB
# 8   119.939744       RA
# 9   111.859162      ERA
# 10    2.932319      SHO
# 11    2.112465       SV
# 12    1.742101        E

# %% [markdown]
# We can observe the maximum vif value for 'RA' so let's drop 'RA'

# %%
x.drop('RA',axis=1,inplace=True)

# %% [markdown]
# Now,let's check the VIF again

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values Features
# 0     4.250076        R
# 1     2.238746       AB
# 2     2.597917       2B
# 3     3.030073       3B
# 4     4.562014       HR
# 5     2.222720       BB
# 6     2.042786       SO
# 7     1.568151       SB
# 8     3.878177      ERA
# 9     2.651314      SHO
# 10    1.954370       SV
# 11    1.493128        E

# %% [markdown]
# VIF value which are less than 10 are acceptable but here,VIF values is less than 5 which is good for our model.

# %% [markdown]
# # Finding Best Random State:

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=r2_score(y_test,predlr)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best Accuracy Score is: ",maxAccu,"on Random_state: ",maxRS)
# Out:
# Best Accuracy Score is:  0.9291790579976077 on Random_state:  50

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=50,test_size=.30)

# %% [markdown]
# # Linear Regression:

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print('R2_score:',r2_score(y_test,predlr))
print('MAE:',mean_absolute_error(y_test, predlr))
print('MSE:',mean_squared_error(y_test, predlr))
# Out:
# R2_score: 0.9291790579976077
# MAE: 2.4627865987898443
# MSE: 10.163242343651952

# %% [markdown]
# # Lasso Regressor:

# %%
params={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,params)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
predls=ls.predict(x_test)
print('R2_Score:',r2_score(y_test,predls))
print('MAE:',metrics.mean_absolute_error(y_test, predls))
print('MSE:',metrics.mean_squared_error(y_test, predls))
# Out:
# R2_Score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597

# %% [markdown]
# # Ridge Regressor:

# %%
params = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'saga' ,'lsqr', 'sparse_cg', 'sag']}
rd=Ridge()
clf=GridSearchCV(rd,params)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'sag'}

# %%
rd=Ridge(alpha=10.26,solver='sag')
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
pred_rd=rd.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_rd))
print('MAE:',mean_absolute_error(y_test, pred_rd))
print('MSE:',mean_squared_error(y_test, pred_rd))
# Out:
# R2_Score: 0.8231319659119206
# MAE: 4.381448333922149
# MSE: 25.381654669627594

# %% [markdown]
# # Stochastic Gradient Descent Regressor:

# %%
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
# Out:
# R2_Score: 0.9292387638910471
# MAE: 2.7342394325466524
# MSE: 10.1546741793885

# %% [markdown]
# # Cross Validation Score:

# %%
from sklearn.model_selection import cross_val_score
for i in range(2,9):
    cr=cross_val_score(lr,x,y,cv=i)
    cr_mean=cr.mean()
    print("at cv= ", i)
    print('cross val score = ',cr_mean*100)
# Out:
# at cv=  2
# cross val score =  -426.87302135013675
# at cv=  3
# cross val score =  37.19786932243064
# at cv=  4
# cross val score =  37.096536336986055
# at cv=  5
# cross val score =  37.34441230489934
# at cv=  6
# cross val score =  30.240025093157314
# at cv=  7
# cross val score =  19.021418947297217
# at cv=  8
# cross val score =  23.194009444421475

# %%
# Linear Regression
print(cross_val_score(lr,x,y,cv=5).mean())
# Out:
# 0.37344412304899344

# %%
#Lasso Regression
print(cross_val_score(ls,x,y,cv=5).mean())
# Out:
# 0.5206537019436117

# %%
#Ridge Regression
print(cross_val_score(rd,x,y,cv=5).mean())
# Out:
# 0.3501126075791874

# %%
#SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.2729680043159661

# %% [markdown]
# # Hyperparameter Tuning:

# %%
lasso = Lasso()
params={'alpha':[0.01,0.1,.001,.0001],'max_iter':[1000,1500,2000],'random_state':range(1,100)}
GCV=GridSearchCV(ls,params,cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'alpha': 0.1, 'max_iter': 1000, 'random_state': 1}

# %%
lasso = Lasso(alpha = 0.1,max_iter=1000,random_state=1)
lasso.fit(x_train,y_train)
pred = lasso.predict(x_test)
score = r2_score(y_test,pred)
print("R2 Score :",score*100)
# Out:
# R2 Score : 93.35556634168015

# %% [markdown]
# we got a good r2 score i.e 93.35

# %%
print('Mean Absolute Error: ', mean_absolute_error(y_test,pred))
print('Mean squared Error: ', mean_squared_error(y_test,pred))
print('Root Mean Absolute Error: ', np.sqrt(mean_absolute_error(y_test,pred)))
# Out:
# Mean Absolute Error:  2.684587745669867
# Mean squared Error:  9.535172449914814
# Root Mean Absolute Error:  1.6384711610735987

# %% [markdown]
# Now Let's save our model

# %%
import pickle
filename='Baseball_Case_Study.pkl'
pickle.dump(lasso,open(filename,'wb'))

# %% [markdown]
# # Checking Original and Predicted Values

# %%
a =np.array(y_test)
predicted = np.array(lasso.predict(x_test))
df =  pd.DataFrame({ 'Original' : a,'predicted' :pred,},index = range(len(a))) 
df
# Out:
#    Original  predicted
# 0        68  66.856522
# 1        78  80.901840
# 2        74  75.359718
# 3        88  83.247358
# 4        68  73.334884
# 5        64  66.709135
# 6        92  88.378335
# 7        90  91.201250
# 8       100  98.863323

# %% [markdown]
# we can observe that the predicted values are almost equal to the original values
